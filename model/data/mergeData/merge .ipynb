# %%
import pandas as pd

# %%
df_2022 = pd.read_csv("heart_2022_with_nans.csv")

# %%
df_2022.head()
# Out:
#      State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Alabama  Female     Very good                 0.0               0.0
# 1  Alabama  Female     Excellent                 0.0               0.0
# 2  Alabama  Female     Very good                 2.0               3.0
# 3  Alabama  Female     Excellent                 0.0               0.0
# 4  Alabama  Female          Fair                 2.0               0.0
#
#                                      LastCheckupTime PhysicalActivities  \
# 0  Within past year (anytime less than 12 months ...                 No
# 1                                                NaN                 No
# 2  Within past year (anytime less than 12 months ...                Yes
# 3  Within past year (anytime less than 12 months ...                Yes
# 4  Within past year (anytime less than 12 months ...                Yes
#
#    SleepHours RemovedTeeth HadHeartAttack  ... HeightInMeters  \
# ...

# %%
columns_2022_keep = ['Sex', 
'GeneralHealth', 
'PhysicalHealthDays',
'MentalHealthDays', 
'PhysicalActivities',  
'SleepHours',
'HadStroke', 
'HadAsthma',
'HadSkinCancer',
'HadDiabetes',
'BMI', 
'AlcoholDrinkers',
'RaceEthnicityCategory',
'AgeCategory',
'HadHeartAttack',
'HadKidneyDisease',
'SmokerStatus',
'DifficultyWalking']

# %%
df_2022 = df_2022[columns_2022_keep]

# %%
df_2022.head()
# Out:
#       Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Female     Very good                 0.0               0.0
# 1  Female     Excellent                 0.0               0.0
# 2  Female     Very good                 2.0               3.0
# 3  Female     Excellent                 0.0               0.0
# 4  Female          Fair                 2.0               0.0
#
#   PhysicalActivities  SleepHours HadStroke HadAsthma HadSkinCancer  \
# 0                 No         8.0        No        No            No
# 1                 No         6.0        No        No           Yes
# 2                Yes         5.0        No        No           Yes
# 3                Yes         7.0        No       Yes            No
# 4                Yes         9.0        No        No            No
#
#   HadDiabetes    BMI AlcoholDrinkers     RaceEthnicityCategory  \
# 0         Yes    NaN              No  White only, Non-Hispanic
# ...

# %%
df_2020 = pd.read_csv("heart_2020_cleaned.csv")

# %%
keep_2020 =['Sex',
'GenHealth', 
'PhysicalHealth', 
'MentalHealth', 
'PhysicalActivity', 
'SleepTime',
'Stroke',
'Asthma', 
'SkinCancer',    
'Diabetic', 
'BMI', 
'AlcoholDrinking', 
'Race', 
'AgeCategory',
'HeartDisease', 
'KidneyDisease', 
'Smoking', 
'DiffWalking', ]

# %%
df_2020 = df_2020[keep_2020]

# %%
df_2020.head()
# Out:
#       Sex  GenHealth  PhysicalHealth  MentalHealth PhysicalActivity  \
# 0  Female  Very good             3.0          30.0              Yes
# 1  Female  Very good             0.0           0.0              Yes
# 2    Male       Fair            20.0          30.0              Yes
# 3  Female       Good             0.0           0.0               No
# 4  Female  Very good            28.0           0.0              Yes
#
#    SleepTime Stroke Asthma SkinCancer Diabetic    BMI AlcoholDrinking   Race  \
# 0        5.0     No    Yes        Yes      Yes  16.60              No  White
# 1        7.0    Yes     No         No       No  20.34              No  White
# 2        8.0     No    Yes         No      Yes  26.58              No  White
# 3        6.0     No     No        Yes       No  24.21              No  White
# 4        8.0     No     No         No       No  23.71              No  White
#
#    AgeCategory HeartDisease KidneyDisease Smoking DiffWalking
# ...

# %%
df_2022.head()
# Out:
#       Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0  Female     Very good                 0.0               0.0
# 1  Female     Excellent                 0.0               0.0
# 2  Female     Very good                 2.0               3.0
# 3  Female     Excellent                 0.0               0.0
# 4  Female          Fair                 2.0               0.0
#
#   PhysicalActivities  SleepHours HadStroke HadAsthma HadSkinCancer  \
# 0                 No         8.0        No        No            No
# 1                 No         6.0        No        No           Yes
# 2                Yes         5.0        No        No           Yes
# 3                Yes         7.0        No       Yes            No
# 4                Yes         9.0        No        No            No
#
#   HadDiabetes    BMI AlcoholDrinkers     RaceEthnicityCategory  \
# 0         Yes    NaN              No  White only, Non-Hispanic
# ...

# %%
df_2022.rename(columns={'GeneralHealth': 'GenHealth', 'PhysicalHealthDays': 'PhysicalHealth', 
                               'MentalHealthDays': 'MentalHealth', 'PhysicalActivities': 'PhysicalActivity', 
                               'SleepHours': 'SleepTime', 'HadHeartAttack': 'HeartDisease', 
                               'HadKidneyDisease': 'KidneyDisease', 'DifficultyWalking': 'DiffWalking'}, inplace=True)
# Out:
# /tmp/ipykernel_1177153/3364861494.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.rename(columns={'GeneralHealth': 'GenHealth', 'PhysicalHealthDays': 'PhysicalHealth',

# %%
df_2022.head()
# Out:
#       Sex  GenHealth  PhysicalHealth  MentalHealth PhysicalActivity  \
# 0  Female  Very good             0.0           0.0               No
# 1  Female  Excellent             0.0           0.0               No
# 2  Female  Very good             2.0           3.0              Yes
# 3  Female  Excellent             0.0           0.0              Yes
# 4  Female       Fair             2.0           0.0              Yes
#
#    SleepTime Stroke Asthma SkinCancer Diabetic    BMI AlcoholDrinking  \
# 0        8.0     No     No         No      Yes    NaN              No
# 1        6.0     No     No        Yes       No  26.57              No
# 2        5.0     No     No        Yes       No  25.61              No
# 3        7.0     No    Yes         No       No  23.30              No
# 4        9.0     No     No         No       No  21.77             Yes
#
#                        Race      AgeCategory HeartDisease KidneyDisease  \
# ...

# %%
df_2020.head()
# Out:
#       Sex  GenHealth  PhysicalHealth  MentalHealth PhysicalActivity  \
# 0  Female  Very good             3.0          30.0              Yes
# 1  Female  Very good             0.0           0.0              Yes
# 2    Male       Fair            20.0          30.0              Yes
# 3  Female       Good             0.0           0.0               No
# 4  Female  Very good            28.0           0.0              Yes
#
#    SleepTime Stroke Asthma SkinCancer Diabetic    BMI AlcoholDrinking   Race  \
# 0        5.0     No    Yes        Yes      Yes  16.60              No  White
# 1        7.0    Yes     No         No       No  20.34              No  White
# 2        8.0     No    Yes         No      Yes  26.58              No  White
# 3        6.0     No     No        Yes       No  24.21              No  White
# 4        8.0     No     No         No       No  23.71              No  White
#
#    AgeCategory HeartDisease KidneyDisease Smoking DiffWalking
# ...

# %%
df_2022.rename(columns={'HadStroke': 'Stroke', 'HadAsthma': 'Asthma', 
                              'HadSkinCancer': 'SkinCancer', 'HadDiabetes': 'Diabetic', 
                              'AlcoholDrinkers': 'AlcoholDrinking', 'RaceEthnicityCategory': 'Race'}, inplace=True)
# Out:
# /tmp/ipykernel_1177153/2138172698.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.rename(columns={'HadStroke': 'Stroke', 'HadAsthma': 'Asthma',

# %%
df_2022.rename(columns={"SmokerStatus":"Smoking"}, inplace=True)
# Out:
# /tmp/ipykernel_1177153/1131179177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.rename(columns={"SmokerStatus":"Smoking"}, inplace=True)

# %%
# # Merging datasets based on common columns
# merged_dataset = pd.merge(df_2022, df_2020, on=['Sex', 'AgeCategory', 'BMI'], how='inner')

# %%
# merged_dataset

# %%
df_2022.columns
# Out:
# Index(['Sex', 'GenHealth', 'PhysicalHealth', 'MentalHealth',
#        'PhysicalActivity', 'SleepTime', 'Stroke', 'Asthma', 'SkinCancer',
#        'Diabetic', 'BMI', 'AlcoholDrinking', 'Race', 'AgeCategory',
#        'HeartDisease', 'KidneyDisease', 'Smoking', 'DiffWalking'],
#       dtype='object')

# %%
df_2022.shape
# Out:
# (445132, 18)

# %%
df_2020.columns
# Out:
# Index(['Sex', 'GenHealth', 'PhysicalHealth', 'MentalHealth',
#        'PhysicalActivity', 'SleepTime', 'Stroke', 'Asthma', 'SkinCancer',
#        'Diabetic', 'BMI', 'AlcoholDrinking', 'Race', 'AgeCategory',
#        'HeartDisease', 'KidneyDisease', 'Smoking', 'DiffWalking'],
#       dtype='object')

# %%
df_2020.shape
# Out:
# (319795, 18)

# %%
# Merge datasets
merged_df = pd.merge(df_2022, df_2020, on=['Sex', 'GenHealth', 'PhysicalHealth', 'MentalHealth',
       'PhysicalActivity', 'SleepTime', 'Stroke', 'Asthma', 'SkinCancer',
       'Diabetic', 'BMI', 'AlcoholDrinking', 'Race', 'AgeCategory',
       'HeartDisease', 'KidneyDisease', 'Smoking', 'DiffWalking'], how='outer')

# %%
merged_df.head()
# Out:
#       Sex  GenHealth  PhysicalHealth  MentalHealth PhysicalActivity  \
# 0  Female  Very good             0.0           0.0               No
# 1  Female  Very good             0.0           0.0               No
# 2  Female  Excellent             0.0           0.0               No
# 3  Female  Very good             2.0           3.0              Yes
# 4  Female  Excellent             0.0           0.0              Yes
#
#    SleepTime Stroke Asthma SkinCancer Diabetic    BMI AlcoholDrinking  \
# 0        8.0     No     No         No      Yes    NaN              No
# 1        8.0     No     No         No      Yes    NaN              No
# 2        6.0     No     No        Yes       No  26.57              No
# 3        5.0     No     No        Yes       No  25.61              No
# 4        7.0     No    Yes         No       No  23.30              No
#
#                        Race      AgeCategory HeartDisease KidneyDisease  \
# ...

# %%
merged_df.shape
# Out:
# (764927, 18)

# %%
merged_df.columns
# Out:
# Index(['Sex', 'GenHealth', 'PhysicalHealth', 'MentalHealth',
#        'PhysicalActivity', 'SleepTime', 'Stroke', 'Asthma', 'SkinCancer',
#        'Diabetic', 'BMI', 'AlcoholDrinking', 'Race', 'AgeCategory',
#        'HeartDisease', 'KidneyDisease', 'SmokerStatus', 'DiffWalking',
#        'Smoking'],
#       dtype='object')

# %%
df_2020.columns
# Out:
# Index(['Sex', 'GenHealth', 'PhysicalHealth', 'MentalHealth',
#        'PhysicalActivity', 'SleepTime', 'Stroke', 'Asthma', 'SkinCancer',
#        'Diabetic', 'BMI', 'AlcoholDrinking', 'Race', 'AgeCategory',
#        'HeartDisease', 'KidneyDisease', 'Smoking', 'DiffWalking'],
#       dtype='object')

# %%
# Export merged DataFrame to CSV
merged_df.to_csv('merged_data.csv', index=False)
